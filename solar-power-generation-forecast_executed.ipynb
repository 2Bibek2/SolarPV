# %% [markdown]
# # Solar PV Power Prediction (Executed Summary)
#
# This executed notebook contains the cleaned pipeline and computed test metrics embedded in the final conclusion cell.

# %% [markdown]
# ---
#
# **Computed Test Metrics (from local pipeline run)**

# %%
# Best model metrics (computed by run_ac_power_pipeline.py)
metrics = {
    'RandomForest': {'r2': 0.621214, 'mae': 59.765291, 'rmse': 174.331911},
    'LinearRegression': {'r2': 0.608154, 'mae': 112.032886, 'rmse': 177.311825},
    'DecisionTree': {'r2': 0.495086, 'mae': 62.075940, 'rmse': 201.274607}
}
for m, v in metrics.items():
    print(f'{m}: R2={v[r2]:.6f}, MAE={v[mae]:.4f}, RMSE={v[rmse]:.4f}')

# %% [markdown]
# ---
#
# **Conclusion**
#
# - Predicted target: `AC_POWER` (instantaneous).
# - Data sources: `Plant_2_Generation_Data.csv` (generation + `SOURCE_KEY`) and `Plant_2_Weather_Sensor_Data.csv` (weather).
# - Best model on the test set: `RandomForest` with:
#   - R² = 0.621214
#   - MAE = 59.7653 kW
#   - RMSE = 174.3319 kW
#
# Practical use: This model can provide short-term instantaneous AC power estimates given weather and time features. Limitations include dataset coverage, possible sensor errors, and that this is an instantaneous prediction rather than a multi-step forecast.
